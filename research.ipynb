# %%
import requests

# %%
session = requests.Session()
r = session.get("https://www.openrent.co.uk/rent-calculator-property-value-by-postcode")

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='__RequestVerificationToken', value='CfDJ8A33KeFEI4tCp1_Yb9_wTmzfGqwP4DrI5yO3CXA545dVjYr0ZLm0bG_xZEEnma25-yE9EnWAcn1vlyTQjaLmOtprpoflvEq5G9pOmp91LSkx2ge258ttzyAsiBiJkd6DUZ2jDl8HUHa4KjQ1DZqJcGc', port=None, port_specified=False, domain='www.openrent.co.uk', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'httponly': None}, rfc2109=False)]>

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
#         <meta charset="utf-8" />
#         <meta name="google-site-verification" content="4M-UV28zzkHSyzX4U1SKQIxDHqRZzw5BUCR5znwPf2c" />
#         <meta http-equiv="X-XRDS-Location" content="https://www.openrent.co.uk/yadis.jsp">
#         <title>Rent Calculator: Find the Rental Value of Your Property | OpenRent</title>
#
#         <link rel="manifest" href="/manifest.json?v=XKzRBf21pa3">
#
#
#         <meta name="apple-mobile-web-app-title" content="OpenRent">
#         <meta name="application-name" content="OpenRent">
#
#
#         <link rel="image_src" href="//staticcdn.openrent.co.uk/images/logos/meta/share-graphic-1.jpg" />
#         <meta name="twitter:image" content="https://staticcdn.openrent.co.uk/images/logos/meta/share-graphic-1.jpg">
#             <meta property="og:image" content="http://staticcdn.openrent.co.uk/images/logos/meta/share-graphic-2.jpg" />
# ...

# %%
import pandas as pd

# %%
url = "https://www.bankofengland.co.uk/boeapps/database/Bank-Rate.asp"
r = requests.get(url)
pd.read_html(r.text)
